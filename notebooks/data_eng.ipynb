# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/SP/INMET_SE_SP_A705_BAURU_01-01-2020_A_31-12-2020.CSV", delimiter=";", skiprows=8, encoding="ISO-8859-1")
df.shape
# Out:
# (8784, 20)

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                                0
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                938
# 1                                              938,7
# 2                                              938,4
# 3                                                938
# 4                                              937,9
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           938,1
# 1                                           938,7
# 2                                           938,7
# 3                                           938,4
# ...

# %%
from os import listdir
from os.path import isfile, join
path = '../raw_data/SP'
files = [f for f in listdir(path) if isfile(join(path, f))]
print(files[0])
# Out:
# INMET_SE_SP_A768_TUPA_01-01-2021_A_31-12-2021.CSV

# %%
df = pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', skiprows=8, encoding="ISO-8859-1")
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2021/01/01  0000 UTC                                0
# 1  2021/01/01  0100 UTC                                0
# 2  2021/01/01  0200 UTC                                0
# 3  2021/01/01  0300 UTC                                0
# 4  2021/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              957,9
# 1                                                958
# 2                                              957,4
# 3                                              956,6
# 4                                                957
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           957,9
# 1                                           958,3
# 2                                             958
# 3                                           957,4
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
clean_df = df.drop(columns=['Unnamed: 19']).copy()
clean_df
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                                0
# 1     2021/01/01  0100 UTC                                0
# 2     2021/01/01  0200 UTC                                0
# 3     2021/01/01  0300 UTC                                0
# 4     2021/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 8755  2021/12/31  1900 UTC                                0
# 8756  2021/12/31  2000 UTC                                0
# 8757  2021/12/31  2100 UTC                                0
# 8758  2021/12/31  2200 UTC                                0
# 8759  2021/12/31  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 957,9
# 1                                                   958
# 2                                                 957,4
# ...

# %%
clean_df.isnull().sum().sort_values(ascending=False)/len(df)
# Out:
# RADIACAO GLOBAL (Kj/m²)                                  0.483219
# VENTO, RAJADA MAXIMA (m/s)                               0.196347
# VENTO, VELOCIDADE HORARIA (m/s)                          0.196005
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     0.196005
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         0.042694
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         0.042580
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 0.042466
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 0.042466
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     0.042009
# UMIDADE RELATIVA DO AR, HORARIA (%)                      0.041895
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          0.041667
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         0.041667
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               0.041553
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               0.041553
# ...

# %%
clean_df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
imputer.fit_transform(df[['VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 from sklearn.impute import KNNImputer
#       2 imputer = KNNImputer(n_neighbors=2)
# ----> 3 imputer.fit_transform(df[['VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))']])
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/sklearn/base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
# ...
