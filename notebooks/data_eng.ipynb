# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/SP/INMET_SE_SP_A705_BAURU_01-01-2020_A_31-12-2020.CSV", delimiter=";", skiprows=8, encoding="ISO-8859-1")
df.shape
# Out:
# (8784, 20)

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                                0
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                938
# 1                                              938,7
# 2                                              938,4
# 3                                                938
# 4                                              937,9
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           938,1
# 1                                           938,7
# 2                                           938,7
# 3                                           938,4
# 4                                             938
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                            937,5                     NaN
# 1                                            937,9                     NaN
# 2                                            938,4                     NaN
# 3                                              938                     NaN
# 4                                            937,9                     NaN
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         24,1
# 1                                         24,6
# 2                                         23,3
# 3                                         22,4
# 4                                         23,1
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                 19,9
# 1                                 19,3
# 2                                   19
# 3                                 19,1
# 4                                   19
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                         26
# 1                                       25,3
# 2                                       24,8
# 3                                       23,3
# 4                                       23,2
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       23,9
# 1                                       24,1
# 2                                       23,3
# 3                                       22,4
# 4                                       22,1
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                             19,9
# 1                                             19,9
# 2                                             19,4
# 3                                             19,1
# 4                                             19,2
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                             17,5
# 1                                               18
# 2                                             18,4
# 3                                             18,6
# 4                                             18,6
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        78
# 1                                        77
# 2                                        77
# 3                                        81
# 4                                        82
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        60
# 1                                        64
# 2                                        68
# 3                                        77
# 4                                        75
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   77                                   169
# 1                                   73                                   126
# 2                                   77                                   107
# 3                                   81                                   330
# 4                                   77                                   308
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                        7,1                               1          NaN
# 1                        5,3                              ,4          NaN
# 2                        2,7                               0          NaN
# 3                         ,9                               0          NaN
# 4                        1,4                               0          NaN

# %%
from os import listdir
from os.path import isfile, join
path = '../raw_data/SP'
files = [f for f in listdir(path) if isfile(join(path, f))]
print(files[0])
# Out:
# INMET_SE_SP_A768_TUPA_01-01-2021_A_31-12-2021.CSV

# %%
df = pd.read_csv(f'../raw_data/SP/{files[70]}', sep=';', skiprows=8, encoding="ISO-8859-1", decimal=',')
lat_log_alt = pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', skiprows=4, 
                          nrows=3, encoding="ISO-8859-1", decimal=',', names=['lat_lon_alt','valor'])
df['Estaçao']=files[0].split('_')[4]
df['Latitude']=lat_log_alt['valor'][0] 
df['Longitude']=lat_log_alt['valor'][1] 
df['Altitude']=lat_log_alt['valor'][2]

df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                               0.0
# 1     2021/01/01  0100 UTC                               0.0
# 2     2021/01/01  0200 UTC                               0.0
# 3     2021/01/01  0300 UTC                               0.0
# 4     2021/01/01  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8755  2021/12/31  1900 UTC                               0.0
# 8756  2021/12/31  2000 UTC                               0.2
# 8757  2021/12/31  2100 UTC                               0.0
# 8758  2021/12/31  2200 UTC                               0.0
# 8759  2021/12/31  2300 UTC                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 954.0
# 1                                                 954.6
# 2                                                 954.1
# 3                                                 952.8
# 4                                                 952.0
# ...                                                 ...
# 8755                                              944.7
# 8756                                              945.2
# 8757                                              945.2
# 8758                                              945.6
# 8759                                              946.4
#
#       PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                               954.3
# 1                                               954.6
# 2                                               954.6
# 3                                               954.1
# 4                                               952.8
# ...                                               ...
# 8755                                            944.7
# 8756                                            945.2
# 8757                                            945.2
# 8758                                            945.6
# 8759                                            946.5
#
#       PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                953.6
# 1                                                953.8
# 2                                                954.1
# 3                                                952.8
# 4                                                952.0
# ...                                                ...
# 8755                                             944.4
# 8756                                             944.5
# 8757                                             944.9
# 8758                                             945.0
# 8759                                             945.6
#
#       RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                      2898.1                                          19.9
# 1                         NaN                                          19.5
# 2                         NaN                                          19.4
# 3                         NaN                                          19.3
# 4                         NaN                                          18.8
# ...                       ...                                           ...
# 8755                    540.3                                          24.0
# 8756                    259.5                                          22.4
# 8757                    313.1                                          22.6
# 8758                     33.7                                          22.0
# 8759                      NaN                                          21.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     18.2
# 1                                     18.2
# 2                                     18.3
# 3                                     18.4
# 4                                     17.8
# ...                                    ...
# 8755                                  16.8
# 8756                                  18.7
# 8757                                  19.0
# 8758                                  18.9
# 8759                                  18.8
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                           20.1  ...
# 1                                           20.1  ...
# 2                                           19.6  ...
# 3                                           19.6  ...
# 4                                           19.4  ...
# ...                                          ...  ...
# 8755                                        26.2  ...
# 8756                                        24.0  ...
# 8757                                        23.1  ...
# 8758                                        22.6  ...
# 8759                                        22.2  ...
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                         87.0
# 1                                         90.0
# 2                                         92.0
# 3                                         94.0
# 4                                         94.0
# ...                                        ...
# 8755                                      63.0
# 8756                                      64.0
# 8757                                      77.0
# 8758                                      79.0
# 8759                                      81.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                    90.0
# 1                                    92.0
# 2                                    94.0
# 3                                    94.0
# 4                                    94.0
# ...                                   ...
# 8755                                 64.0
# 8756                                 80.0
# 8757                                 80.0
# 8758                                 82.0
# 8759                                 85.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                    259.0                         7.8
# 1                                    322.0                         3.5
# 2                                    261.0                         2.4
# 3                                    196.0                         2.4
# 4                                    323.0                         1.4
# ...                                    ...                         ...
# 8755                                 210.0                         7.6
# 8756                                 216.0                         3.9
# 8757                                 200.0                         4.7
# 8758                                 249.0                         4.7
# 8759                                 206.0                         3.8
#
#       VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19  Estaçao   Latitude  \
# 0                                 0.3          NaN     TUPA -21.927251
# 1                                 1.3          NaN     TUPA -21.927251
# 2                                 1.9          NaN     TUPA -21.927251
# 3                                 0.3          NaN     TUPA -21.927251
# 4                                 0.0          NaN     TUPA -21.927251
# ...                               ...          ...      ...        ...
# 8755                              2.1          NaN     TUPA -21.927251
# 8756                              0.7          NaN     TUPA -21.927251
# 8757                              2.8          NaN     TUPA -21.927251
# 8758                              0.0          NaN     TUPA -21.927251
# 8759                              0.0          NaN     TUPA -21.927251
#
#       Longitude  Altitude
# 0    -50.490251     498.0
# 1    -50.490251     498.0
# 2    -50.490251     498.0
# 3    -50.490251     498.0
# 4    -50.490251     498.0
# ...         ...       ...
# 8755 -50.490251     498.0
# 8756 -50.490251     498.0
# 8757 -50.490251     498.0
# 8758 -50.490251     498.0
# 8759 -50.490251     498.0
#
# [8760 rows x 24 columns]

# %%
lat_log_alt
# Out:
#   lat_lon_alt      valor
# 0   LATITUDE: -23.810833
# 1  LONGITUDE: -45.402500
# 2   ALTITUDE:  24.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
clean_df = df.drop(columns=['Unnamed: 19']).copy()
clean_df
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                               0.0
# 1     2021/01/01  0100 UTC                               0.0
# 2     2021/01/01  0200 UTC                               0.0
# 3     2021/01/01  0300 UTC                               0.0
# 4     2021/01/01  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8755  2021/12/31  1900 UTC                               0.0
# 8756  2021/12/31  2000 UTC                               0.2
# 8757  2021/12/31  2100 UTC                               0.0
# 8758  2021/12/31  2200 UTC                               0.0
# 8759  2021/12/31  2300 UTC                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 954.0
# 1                                                 954.6
# 2                                                 954.1
# 3                                                 952.8
# 4                                                 952.0
# ...                                                 ...
# 8755                                              944.7
# 8756                                              945.2
# 8757                                              945.2
# 8758                                              945.6
# 8759                                              946.4
#
#       PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                               954.3
# 1                                               954.6
# 2                                               954.6
# 3                                               954.1
# 4                                               952.8
# ...                                               ...
# 8755                                            944.7
# 8756                                            945.2
# 8757                                            945.2
# 8758                                            945.6
# 8759                                            946.5
#
#       PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                953.6
# 1                                                953.8
# 2                                                954.1
# 3                                                952.8
# 4                                                952.0
# ...                                                ...
# 8755                                             944.4
# 8756                                             944.5
# 8757                                             944.9
# 8758                                             945.0
# 8759                                             945.6
#
#       RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                      2898.1                                          19.9
# 1                         NaN                                          19.5
# 2                         NaN                                          19.4
# 3                         NaN                                          19.3
# 4                         NaN                                          18.8
# ...                       ...                                           ...
# 8755                    540.3                                          24.0
# 8756                    259.5                                          22.4
# 8757                    313.1                                          22.6
# 8758                     33.7                                          22.0
# 8759                      NaN                                          21.5
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     18.2
# 1                                     18.2
# 2                                     18.3
# 3                                     18.4
# 4                                     17.8
# ...                                    ...
# 8755                                  16.8
# 8756                                  18.7
# 8757                                  19.0
# 8758                                  18.9
# 8759                                  18.8
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                           20.1  ...
# 1                                           20.1  ...
# 2                                           19.6  ...
# 3                                           19.6  ...
# 4                                           19.4  ...
# ...                                          ...  ...
# 8755                                        26.2  ...
# 8756                                        24.0  ...
# 8757                                        23.1  ...
# 8758                                        22.6  ...
# 8759                                        22.2  ...
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                         90.0
# 1                                         92.0
# 2                                         94.0
# 3                                         94.0
# 4                                         94.0
# ...                                        ...
# 8755                                      70.0
# 8756                                      81.0
# 8757                                      81.0
# 8758                                      82.0
# 8759                                      85.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                         87.0
# 1                                         90.0
# 2                                         92.0
# 3                                         94.0
# 4                                         94.0
# ...                                        ...
# 8755                                      63.0
# 8756                                      64.0
# 8757                                      77.0
# 8758                                      79.0
# 8759                                      81.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                    90.0
# 1                                    92.0
# 2                                    94.0
# 3                                    94.0
# 4                                    94.0
# ...                                   ...
# 8755                                 64.0
# 8756                                 80.0
# 8757                                 80.0
# 8758                                 82.0
# 8759                                 85.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                    259.0                         7.8
# 1                                    322.0                         3.5
# 2                                    261.0                         2.4
# 3                                    196.0                         2.4
# 4                                    323.0                         1.4
# ...                                    ...                         ...
# 8755                                 210.0                         7.6
# 8756                                 216.0                         3.9
# 8757                                 200.0                         4.7
# 8758                                 249.0                         4.7
# 8759                                 206.0                         3.8
#
#       VENTO, VELOCIDADE HORARIA (m/s)  Estaçao   Latitude  Longitude Altitude
# 0                                 0.3     TUPA -21.927251 -50.490251    498.0
# 1                                 1.3     TUPA -21.927251 -50.490251    498.0
# 2                                 1.9     TUPA -21.927251 -50.490251    498.0
# 3                                 0.3     TUPA -21.927251 -50.490251    498.0
# 4                                 0.0     TUPA -21.927251 -50.490251    498.0
# ...                               ...      ...        ...        ...      ...
# 8755                              2.1     TUPA -21.927251 -50.490251    498.0
# 8756                              0.7     TUPA -21.927251 -50.490251    498.0
# 8757                              2.8     TUPA -21.927251 -50.490251    498.0
# 8758                              0.0     TUPA -21.927251 -50.490251    498.0
# 8759                              0.0     TUPA -21.927251 -50.490251    498.0
#
# [8760 rows x 23 columns]

# %%
clean_df.isnull().sum().sort_values(ascending=False)/len(df)
# Out:
# RADIACAO GLOBAL (Kj/m²)                                  0.474315
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         0.085274
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         0.000571
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     0.000457
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         0.000228
# VENTO, RAJADA MAXIMA (m/s)                               0.000228
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     0.000228
# UMIDADE RELATIVA DO AR, HORARIA (%)                      0.000228
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 0.000228
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 0.000228
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               0.000228
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               0.000228
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             0.000228
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         0.000228
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          0.000228
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    0.000228
# VENTO, VELOCIDADE HORARIA (m/s)                          0.000228
# Longitude                                                0.000000
# Latitude                                                 0.000000
# Data                                                     0.000000
# Estaçao                                                  0.000000
# Hora UTC                                                 0.000000
# Altitude                                                 0.000000
# dtype: float64

# %%
clean_df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         float64
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    float64
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          float64
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         float64
# RADIACAO GLOBAL (Kj/m²)                                  float64
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             float64
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     float64
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               float64
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               float64
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         float64
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         float64
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE RELATIVA DO AR, HORARIA (%)                      float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     float64
# VENTO, RAJADA MAXIMA (m/s)                               float64
# VENTO, VELOCIDADE HORARIA (m/s)                          float64
# Estaçao                                                   object
# Latitude                                                 float64
# Longitude                                                float64
# Altitude                                                 float64
# dtype: object

# %%
clean_df['VENTO, RAJADA MAXIMA (m/s)']
# Out:
# 0       7.8
# 1       3.5
# 2       2.4
# 3       2.4
# 4       1.4
#        ...
# 8755    7.6
# 8756    3.9
# 8757    4.7
# 8758    4.7
# 8759    3.8
# Name: VENTO, RAJADA MAXIMA (m/s), Length: 8760, dtype: float64

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
imputer.fit_transform(df[['VENTO, RAJADA MAXIMA (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))']])
# Out:
# array([[7.80e+00, 3.00e-01, 2.59e+02],
#        [3.50e+00, 1.30e+00, 3.22e+02],
#        [2.40e+00, 1.90e+00, 2.61e+02],
#        ...,
#        [4.70e+00, 2.80e+00, 2.00e+02],
#        [4.70e+00, 0.00e+00, 2.49e+02],
#        [3.80e+00, 0.00e+00, 2.06e+02]])

# %%
df_test_mudar_nome_col = clean_df.rename(columns={'Data': 'Data',
                                            'Hora UTC': 'Hora(UTC)',
                                            'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'Chuva',
                                            'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)': 'Pres',
                                            'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)': 'Pres.max',
                                            'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)': 'Pres.min',
                                            'RADIACAO GLOBAL (Kj/m²)': 'Radiacao',
                                            'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'Temp',
                                            'TEMPERATURA DO PONTO DE ORVALHO (°C)': 'Temp.orvalho',
                                            'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)': 'Temp.max',
                                            'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)': 'Temp.min',
                                            'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)': 'Temp.orvalho.max',
                                            'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)': 'Temp.orvalho.min',
                                            'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)': 'Umid.max',
                                            'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)': 'Umid.min',
                                            'UMIDADE RELATIVA DO AR, HORARIA (%)': 'Umid',
                                            'VENTO, DIREÇÃO HORARIA (gr) (° (gr))': 'Dir.vento',
                                            'VENTO, RAJADA MAXIMA (m/s)': 'Rajada.vento',
                                            'VENTO, VELOCIDADE HORARIA (m/s)': 'Vel.vento'})
df_test_mudar_nome_col
# Out:
#             Data Hora(UTC)  Chuva   Pres  Pres.max  Pres.min  Radiacao  Temp  \
# 0     2021/01/01  0000 UTC    0.0  954.0     954.3     953.6    2898.1  19.9
# 1     2021/01/01  0100 UTC    0.0  954.6     954.6     953.8       NaN  19.5
# 2     2021/01/01  0200 UTC    0.0  954.1     954.6     954.1       NaN  19.4
# 3     2021/01/01  0300 UTC    0.0  952.8     954.1     952.8       NaN  19.3
# 4     2021/01/01  0400 UTC    0.0  952.0     952.8     952.0       NaN  18.8
# ...          ...       ...    ...    ...       ...       ...       ...   ...
# 8755  2021/12/31  1900 UTC    0.0  944.7     944.7     944.4     540.3  24.0
# 8756  2021/12/31  2000 UTC    0.2  945.2     945.2     944.5     259.5  22.4
# 8757  2021/12/31  2100 UTC    0.0  945.2     945.2     944.9     313.1  22.6
# 8758  2021/12/31  2200 UTC    0.0  945.6     945.6     945.0      33.7  22.0
# 8759  2021/12/31  2300 UTC    0.0  946.4     946.5     945.6       NaN  21.5
#
#       Temp.orvalho  Temp.max  ...  Umid.max  Umid.min  Umid  Dir.vento  \
# 0             18.2      20.1  ...      90.0      87.0  90.0      259.0
# 1             18.2      20.1  ...      92.0      90.0  92.0      322.0
# 2             18.3      19.6  ...      94.0      92.0  94.0      261.0
# 3             18.4      19.6  ...      94.0      94.0  94.0      196.0
# 4             17.8      19.4  ...      94.0      94.0  94.0      323.0
# ...            ...       ...  ...       ...       ...   ...        ...
# 8755          16.8      26.2  ...      70.0      63.0  64.0      210.0
# 8756          18.7      24.0  ...      81.0      64.0  80.0      216.0
# 8757          19.0      23.1  ...      81.0      77.0  80.0      200.0
# 8758          18.9      22.6  ...      82.0      79.0  82.0      249.0
# 8759          18.8      22.2  ...      85.0      81.0  85.0      206.0
#
#       Rajada.vento  Vel.vento  Estaçao   Latitude  Longitude Altitude
# 0              7.8        0.3     TUPA -21.927251 -50.490251    498.0
# 1              3.5        1.3     TUPA -21.927251 -50.490251    498.0
# 2              2.4        1.9     TUPA -21.927251 -50.490251    498.0
# 3              2.4        0.3     TUPA -21.927251 -50.490251    498.0
# 4              1.4        0.0     TUPA -21.927251 -50.490251    498.0
# ...            ...        ...      ...        ...        ...      ...
# 8755           7.6        2.1     TUPA -21.927251 -50.490251    498.0
# 8756           3.9        0.7     TUPA -21.927251 -50.490251    498.0
# 8757           4.7        2.8     TUPA -21.927251 -50.490251    498.0
# 8758           4.7        0.0     TUPA -21.927251 -50.490251    498.0
# 8759           3.8        0.0     TUPA -21.927251 -50.490251    498.0
#
# [8760 rows x 23 columns]

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
imputer.fit_transform(df[['Rajada.vento', 'Vel.vento', 'Dir.vento']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/qv/0_g1qrz929d9jr96xtzst0cm0000gn/T/ipykernel_15569/3638388617.py in <module>
#       1 from sklearn.impute import KNNImputer
#       2 imputer = KNNImputer(n_neighbors=2)
# ----> 3 imputer.fit_transform(df[['Rajada.vento', 'Vel.vento', 'Dir.vento']])
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Rajada.vento', 'Vel.vento', 'Dir.vento'], dtype='object')] are in the [columns]"

# %%
import datetime

df['Data']= pd.to_datetime(df['Data'])
df
# Out:
#            Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0    2020-01-01  0000 UTC                               0.0
# 1    2020-01-01  0100 UTC                               0.0
# 2    2020-01-01  0200 UTC                               0.0
# 3    2020-01-01  0300 UTC                               0.0
# 4    2020-01-01  0400 UTC                               0.0
# ...         ...       ...                               ...
# 8779 2020-12-31  1900 UTC                               NaN
# 8780 2020-12-31  2000 UTC                               NaN
# 8781 2020-12-31  2100 UTC                               NaN
# 8782 2020-12-31  2200 UTC                               NaN
# 8783 2020-12-31  2300 UTC                               NaN
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                1007.7
# 1                                                1008.7
# 2                                                1008.7
# 3                                                1008.1
# 4                                                1007.2
# ...                                                 ...
# 8779                                                NaN
# 8780                                                NaN
# 8781                                                NaN
# 8782                                                NaN
# 8783                                                NaN
#
#       PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                              1007.8
# 1                                              1008.7
# 2                                              1008.8
# 3                                              1008.7
# 4                                              1008.1
# ...                                               ...
# 8779                                              NaN
# 8780                                              NaN
# 8781                                              NaN
# 8782                                              NaN
# 8783                                              NaN
#
#       PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                               1007.5
# 1                                               1007.7
# 2                                               1008.6
# 3                                               1008.1
# 4                                               1007.2
# ...                                                ...
# 8779                                               NaN
# 8780                                               NaN
# 8781                                               NaN
# 8782                                               NaN
# 8783                                               NaN
#
#       RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                         NaN                                          26.2
# 1                         NaN                                          26.9
# 2                         NaN                                          26.0
# 3                         NaN                                          25.4
# 4                         NaN                                          25.0
# ...                       ...                                           ...
# 8779                      NaN                                           NaN
# 8780                      NaN                                           NaN
# 8781                      NaN                                           NaN
# 8782                      NaN                                           NaN
# 8783                      NaN                                           NaN
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                     20.3
# 1                                     20.7
# 2                                     21.1
# 3                                     21.4
# 4                                     21.2
# ...                                    ...
# 8779                                   NaN
# 8780                                   NaN
# 8781                                   NaN
# 8782                                   NaN
# 8783                                   NaN
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                           26.9  ...
# 1                                           27.0  ...
# 2                                           27.1  ...
# 3                                           26.0  ...
# 4                                           25.5  ...
# ...                                          ...  ...
# 8779                                         NaN  ...
# 8780                                         NaN  ...
# 8781                                         NaN  ...
# 8782                                         NaN  ...
# 8783                                         NaN  ...
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                         67.0
# 1                                         68.0
# 2                                         69.0
# 3                                         75.0
# 4                                         79.0
# ...                                        ...
# 8779                                       NaN
# 8780                                       NaN
# 8781                                       NaN
# 8782                                       NaN
# 8783                                       NaN
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                    70.0
# 1                                    69.0
# 2                                    75.0
# 3                                    79.0
# 4                                    79.0
# ...                                   ...
# 8779                                  NaN
# 8780                                  NaN
# 8781                                  NaN
# 8782                                  NaN
# 8783                                  NaN
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                    196.0                         7.4
# 1                                    216.0                         6.4
# 2                                    242.0                         6.2
# 3                                    276.0                         6.0
# 4                                    283.0                         5.4
# ...                                    ...                         ...
# 8779                                   NaN                         NaN
# 8780                                   NaN                         NaN
# 8781                                   NaN                         NaN
# 8782                                   NaN                         NaN
# 8783                                   NaN                         NaN
#
#       VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19        Estaçao   Latitude  \
# 0                                 3.5          NaN  SAO SEBASTIAO -23.810833
# 1                                 4.0          NaN  SAO SEBASTIAO -23.810833
# 2                                 3.8          NaN  SAO SEBASTIAO -23.810833
# 3                                 3.7          NaN  SAO SEBASTIAO -23.810833
# 4                                 3.8          NaN  SAO SEBASTIAO -23.810833
# ...                               ...          ...            ...        ...
# 8779                              NaN          NaN  SAO SEBASTIAO -23.810833
# 8780                              NaN          NaN  SAO SEBASTIAO -23.810833
# 8781                              NaN          NaN  SAO SEBASTIAO -23.810833
# 8782                              NaN          NaN  SAO SEBASTIAO -23.810833
# 8783                              NaN          NaN  SAO SEBASTIAO -23.810833
#
#       Longitude  Altitude
# 0      -45.4025      24.0
# 1      -45.4025      24.0
# 2      -45.4025      24.0
# 3      -45.4025      24.0
# 4      -45.4025      24.0
# ...         ...       ...
# 8779   -45.4025      24.0
# 8780   -45.4025      24.0
# 8781   -45.4025      24.0
# 8782   -45.4025      24.0
# 8783   -45.4025      24.0
#
# [8784 rows x 24 columns]

# %%
df2['Radiacao'] = df2['Radiacao'].replace(np.nan, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qv/0_g1qrz929d9jr96xtzst0cm0000gn/T/ipykernel_15569/964950496.py in <module>
# ----> 1 df2['Radiacao'] = df2['Radiacao'].replace(np.nan, 0)
#
# NameError: name 'df2' is not defined
