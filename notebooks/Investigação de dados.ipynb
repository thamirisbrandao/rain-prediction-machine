# %% [markdown]
# # Importações

# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
import numpy as np
from sklearn.impute import KNNImputer

# %% [markdown]
# # Criando variáveis organizacionais

# %%
path = '../raw_data/SP' #caminho geral
files = [f for f in listdir(path) if isfile(join(path, f))] #lista de nomes de arquivos de dados

# %% [markdown]
# # Selecionando arquivo

# %%
#---------------------escolher arquivo---------------------

file = int(input("selecionar índice do arquivo desejado"))

df = pd.read_csv(f'../raw_data/SP/{files[file]}', sep=';', skiprows=8, encoding="ISO-8859-1", decimal=',')
lat_log_alt = pd.read_csv(f'../raw_data/SP/{files[file]}', sep=';', skiprows=4,
                          nrows=3, encoding="ISO-8859-1", decimal=',', names=['lat_lon_alt','valor'])

df['Estaçao']=files[file].split('_')[4]
df['Latitude']=lat_log_alt['valor'][0]
df['Longitude']=lat_log_alt['valor'][1]
df['Altitude']=lat_log_alt['valor'][2]

#---------------------dropar coluna inútil---------------------
df.drop(columns=["Unnamed: 19"],inplace=True)

#---------------------mudar nome das colunas---------------------
df= df.rename(columns={'Data': 'Data',
                                            'Hora UTC': 'Hora(UTC)',
                                            'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'Chuva',
                                            'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)': 'Pres',
                                            'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)': 'Pres.max',
                                            'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)': 'Pres.min',
                                            'RADIACAO GLOBAL (Kj/m²)': 'Radiacao',
                                            'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'Temp',
                                            'TEMPERATURA DO PONTO DE ORVALHO (°C)': 'Temp.orvalho',
                                            'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)': 'Temp.max',
                                            'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)': 'Temp.min',
                                            'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)': 'Temp.orvalho.max',
                                            'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)': 'Temp.orvalho.min',
                                            'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)': 'Umid.max',
                                            'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)': 'Umid.min',
                                            'UMIDADE RELATIVA DO AR, HORARIA (%)': 'Umid',
                                            'VENTO, DIREÇÃO HORARIA (gr) (° (gr))': 'Dir.vento',
                                            'VENTO, RAJADA MAXIMA (m/s)': 'Rajada.vento',
                                            'VENTO, VELOCIDADE HORARIA (m/s)': 'Vel.vento'})
df
# Out:
# selecionar índice do arquivo desejado11
#             Data Hora(UTC)  Chuva   Pres  Pres.max  Pres.min  Radiacao  Temp  \
# 0     2021/01/01  0000 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# 1     2021/01/01  0100 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# 2     2021/01/01  0200 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# 3     2021/01/01  0300 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# 4     2021/01/01  0400 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# ...          ...       ...    ...    ...       ...       ...       ...   ...
# 8755  2021/12/31  1900 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# 8756  2021/12/31  2000 UTC    0.0  945.2     946.0     945.1    1385.9  23.7
# 8757  2021/12/31  2100 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# 8758  2021/12/31  2200 UTC    NaN    NaN       NaN       NaN       NaN   NaN
# 8759  2021/12/31  2300 UTC    NaN    NaN       NaN       NaN       NaN   NaN
#
#       Temp.orvalho  Temp.max  ...  Umid.max  Umid.min  Umid  Dir.vento  \
# 0              NaN       NaN  ...       NaN       NaN   NaN        NaN
# 1              NaN       NaN  ...       NaN       NaN   NaN        NaN
# 2              NaN       NaN  ...       NaN       NaN   NaN        NaN
# 3              NaN       NaN  ...       NaN       NaN   NaN        NaN
# 4              NaN       NaN  ...       NaN       NaN   NaN        NaN
# ...            ...       ...  ...       ...       ...   ...        ...
# 8755           NaN       NaN  ...       NaN       NaN   NaN        NaN
# 8756          19.8      24.4  ...      89.0      79.0  79.0      113.0
# 8757           NaN       NaN  ...       NaN       NaN   NaN        NaN
# 8758           NaN       NaN  ...       NaN       NaN   NaN        NaN
# 8759           NaN       NaN  ...       NaN       NaN   NaN        NaN
#
#       Rajada.vento  Vel.vento   Estaçao   Latitude  Longitude Altitude
# 0              NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# 1              NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# 2              NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# 3              NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# 4              NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# ...            ...        ...       ...        ...        ...      ...
# 8755           NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# 8756           4.6        0.3  ARIRANHA -21.133056 -48.840556   525.44
# 8757           NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# 8758           NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
# 8759           NaN        NaN  ARIRANHA -21.133056 -48.840556   525.44
#
# [8760 rows x 23 columns]
