# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
df = pd.read_csv("../raw_data/SP/INMET_SE_SP_A705_BAURU_01-01-2020_A_31-12-2020.CSV", delimiter=";", skiprows=8, encoding="ISO-8859-1")
df
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2020/01/01  0000 UTC                                0
# 1     2020/01/01  0100 UTC                                0
# 2     2020/01/01  0200 UTC                                0
# 3     2020/01/01  0300 UTC                                0
# 4     2020/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 8779  2020/12/31  1900 UTC                              2,8
# 8780  2020/12/31  2000 UTC                               ,8
# 8781  2020/12/31  2100 UTC                                0
# 8782  2020/12/31  2200 UTC                               ,8
# 8783  2020/12/31  2300 UTC                              1,8
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                   938
# 1                                                 938,7
# 2                                                 938,4
# 3                                                   938
# 4                                                 937,9
# ...                                                 ...
# 8779                                              941,1
# 8780                                              941,3
# 8781                                              941,7
# 8782                                              942,5
# 8783                                              942,4
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                              938,1
# 1                                              938,7
# 2                                              938,7
# 3                                              938,4
# 4                                                938
# ...                                              ...
# 8779                                           942,1
# 8780                                           941,3
# 8781                                           941,7
# 8782                                           942,5
# 8783                                           942,6
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                               937,5                     NaN
# 1                                               937,9                     NaN
# 2                                               938,4                     NaN
# 3                                                 938                     NaN
# 4                                               937,9                     NaN
# ...                                               ...                     ...
# 8779                                            941,1                      76
# 8780                                            940,9                   134,7
# 8781                                            941,1                   198,8
# 8782                                            941,7                    31,3
# 8783                                            942,2                      ,6
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                            24,1
# 1                                            24,6
# 2                                            23,3
# 3                                            22,4
# 4                                            23,1
# ...                                           ...
# 8779                                         20,9
# 8780                                         21,4
# 8781                                         21,8
# 8782                                         20,9
# 8783                                         20,4
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                    19,9
# 1                                    19,3
# 2                                      19
# 3                                    19,1
# 4                                      19
# ...                                   ...
# 8779                                 20,3
# 8780                                 20,8
# 8781                                 21,2
# 8782                                 20,2
# 8783                                 19,8
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                            26
# 1                                          25,3
# 2                                          24,8
# 3                                          23,3
# 4                                          23,2
# ...                                         ...
# 8779                                       22,2
# 8780                                       21,4
# 8781                                         22
# 8782                                       21,9
# 8783                                       20,9
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                          23,9
# 1                                          24,1
# 2                                          23,3
# 3                                          22,4
# 4                                          22,1
# ...                                         ...
# 8779                                       20,8
# 8780                                       20,9
# 8781                                       21,4
# 8782                                       20,9
# 8783                                       20,4
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                                19,9
# 1                                                19,9
# 2                                                19,4
# 3                                                19,1
# 4                                                19,2
# ...                                               ...
# 8779                                             21,5
# 8780                                             20,8
# 8781                                             21,3
# 8782                                             21,3
# 8783                                             20,2
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                                17,5
# 1                                                  18
# 2                                                18,4
# 3                                                18,6
# 4                                                18,6
# ...                                               ...
# 8779                                             20,2
# 8780                                             20,3
# 8781                                             20,8
# 8782                                             20,2
# 8783                                             19,8
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                           78
# 1                                           77
# 2                                           77
# 3                                           81
# 4                                           82
# ...                                        ...
# 8779                                        96
# 8780                                        96
# 8781                                        96
# 8782                                        96
# 8783                                        97
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                           60
# 1                                           64
# 2                                           68
# 3                                           77
# 4                                           75
# ...                                        ...
# 8779                                        95
# 8780                                        96
# 8781                                        96
# 8782                                        95
# 8783                                        96
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                      77
# 1                                      73
# 2                                      77
# 3                                      81
# 4                                      77
# ...                                   ...
# 8779                                   96
# 8780                                   96
# 8781                                   96
# 8782                                   96
# 8783                                   97
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 0                                      169                        7,1
# 1                                      126                        5,3
# 2                                      107                        2,7
# 3                                      330                         ,9
# 4                                      308                        1,4
# ...                                    ...                        ...
# 8779                                   135                        4,6
# 8780                                    97                          0
# 8781                                   155                          0
# 8782                                   124                        4,7
# 8783                                    88                          0
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                                  1          NaN
# 1                                 ,4          NaN
# 2                                  0          NaN
# 3                                  0          NaN
# 4                                  0          NaN
# ...                              ...          ...
# 8779                               0          NaN
# 8780                               0          NaN
# 8781                               0          NaN
# 8782                               0          NaN
# 8783                               0          NaN
#
# [8784 rows x 20 columns]

# %%
df = pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', skiprows=8, encoding="ISO-8859-1", decimal=',')
lat_log_alt = pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', skiprows=3, nrows=3, encoding="ISO-8859-1", decimal=',')
df['Estaçao']=files[0].split('_')[4]
df['Latitude']=lat_log_alt['A768'][0] 
df['Longitude']=lat_log_alt['A768'][1] 
df['Altitude']=lat_log_alt['A768'][2]

df.head()

# %%
path = '../raw_data/SP'
files = [f for f in listdir(path) if isfile(join(path, f))]
print(files[0])
# Out:
# INMET_SE_SP_A771_SAO PAULO - INTERLAGOS_01-01-2020_A_31-12-2020.CSV

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE RELATIVA DO AR, HORARIA (%)                      float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     float64
# VENTO, RAJADA MAXIMA (m/s)                                object
# VENTO, VELOCIDADE HORARIA (m/s)                           object
# Unnamed: 19                                              float64
# Estaçao                                                   object
# dtype: object

# %%
teste=df
teste['estacao']=files[0].split('_')[4]
teste.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                                0
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                938
# 1                                              938,7
# 2                                              938,4
# 3                                                938
# 4                                              937,9
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           938,1
# 1                                           938,7
# 2                                           938,7
# 3                                           938,4
# 4                                             938
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                            937,5                     NaN
# 1                                            937,9                     NaN
# 2                                            938,4                     NaN
# 3                                              938                     NaN
# 4                                            937,9                     NaN
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         24,1
# 1                                         24,6
# 2                                         23,3
# 3                                         22,4
# 4                                         23,1
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                 19,9
# 1                                 19,3
# 2                                   19
# 3                                 19,1
# 4                                   19
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                         26  ...
# 1                                       25,3  ...
# 2                                       24,8  ...
# 3                                       23,3  ...
# 4                                       23,2  ...
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                             19,9
# 1                                             19,9
# 2                                             19,4
# 3                                             19,1
# 4                                             19,2
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                             17,5
# 1                                               18
# 2                                             18,4
# 3                                             18,6
# 4                                             18,6
#
#   UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                       78
# 1                                       77
# 2                                       77
# 3                                       81
# 4                                       82
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        60
# 1                                        64
# 2                                        68
# 3                                        77
# 4                                        75
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   77                                   169
# 1                                   73                                   126
# 2                                   77                                   107
# 3                                   81                                   330
# 4                                   77                                   308
#
#    VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s) Unnamed: 19  \
# 0                         7,1                               1         NaN
# 1                         5,3                              ,4         NaN
# 2                         2,7                               0         NaN
# 3                          ,9                               0         NaN
# 4                         1,4                               0         NaN
#
#                   estacao
# 0  SAO PAULO - INTERLAGOS
# 1  SAO PAULO - INTERLAGOS
# 2  SAO PAULO - INTERLAGOS
# 3  SAO PAULO - INTERLAGOS
# 4  SAO PAULO - INTERLAGOS
#
# [5 rows x 21 columns]

# %%
df = pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', skiprows=8, encoding="ISO-8859-1")
df['Estaçao']=files[0].split('_')[4]

# %%
df = pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', skiprows=8, encoding="ISO-8859-1")
header=pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', nrows=7, encoding="ISO-8859-1")
df['Estaçao']=header['SE'][1] 
df['Latitude']=header['SE'][3] 
df['Longitude']=header['SE'][4] 
df['Altitude']=header['SE'][5] 
df
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2020/01/01  0000 UTC                                0
# 1     2020/01/01  0100 UTC                                0
# 2     2020/01/01  0200 UTC                                0
# 3     2020/01/01  0300 UTC                                0
# 4     2020/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 8779  2020/12/31  1900 UTC                                0
# 8780  2020/12/31  2000 UTC                                0
# 8781  2020/12/31  2100 UTC                               ,8
# 8782  2020/12/31  2200 UTC                              9,2
# 8783  2020/12/31  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 923,1
# 1                                                 923,7
# 2                                                 923,6
# 3                                                 923,1
# 4                                                 922,6
# ...                                                 ...
# 8779                                              924,3
# 8780                                              925,7
# 8781                                              926,3
# 8782                                              926,5
# 8783                                                926
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                              923,1
# 1                                              923,7
# 2                                              923,8
# 3                                              923,6
# 4                                              923,1
# ...                                              ...
# 8779                                           924,6
# 8780                                           925,7
# 8781                                           926,3
# 8782                                           926,6
# 8783                                           926,5
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                               922,1                     NaN
# 1                                               923,1                     NaN
# 2                                               923,6                     NaN
# 3                                               923,1                     NaN
# 4                                               922,6                     NaN
# ...                                               ...                     ...
# 8779                                            924,2                   806,8
# 8780                                            924,3                   315,1
# 8781                                            925,7                   113,8
# 8782                                            926,2                    10,7
# 8783                                              926                     NaN
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                              22
# 1                                            22,1
# 2                                            23,2
# 3                                            23,3
# 4                                            22,9
# ...                                           ...
# 8779                                         24,5
# 8780                                         23,9
# 8781                                         21,9
# 8782                                         20,4
# 8783                                         19,9
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                    20,5
# 1                                    20,7
# 2                                    20,1
# 3                                    19,5
# 4                                      19
# ...                                   ...
# 8779                                 18,8
# 8780                                 19,2
# 8781                                   21
# 8782                                 19,9
# 8783                                 19,4
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                          22,2  ...
# 1                                          22,3  ...
# 2                                          23,5  ...
# 3                                          23,6  ...
# 4                                          23,6  ...
# ...                                         ...  ...
# 8779                                       25,5  ...
# 8780                                         25  ...
# 8781                                       23,9  ...
# 8782                                       21,9  ...
# 8783                                       20,4  ...
#
#      UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        90.0
# 1                                        90.0
# 2                                        82.0
# 3                                        78.0
# 4                                        76.0
# ...                                       ...
# 8779                                     67.0
# 8780                                     68.0
# 8781                                     74.0
# 8782                                     91.0
# 8783                                     96.0
#
#      UMIDADE RELATIVA DO AR, HORARIA (%) VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                   92.0                                172.0
# 1                                   92.0                                101.0
# 2                                   82.0                                  7.0
# 3                                   79.0                                  6.0
# 4                                   79.0                                345.0
# ...                                  ...                                  ...
# 8779                                71.0                                315.0
# 8780                                75.0                                286.0
# 8781                                94.0                                293.0
# 8782                                97.0                                281.0
# 8783                                97.0                                331.0
#
#       VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  \
# 0                            2,8                               ,4
# 1                            1,8                               ,9
# 2                            3,3                              1,2
# 3                              3                              1,2
# 4                            3,5                               ,6
# ...                          ...                              ...
# 8779                         7,3                              2,2
# 8780                         6,2                              1,3
# 8781                         4,6                               ,8
# 8782                         8,5                              1,7
# 8783                         5,7                              1,9
#
#       Unnamed: 19                 Estaçao    Latitude   Longitude  Altitude
# 0             NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 1             NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 2             NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 3             NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 4             NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# ...           ...                     ...         ...         ...       ...
# 8779          NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 8780          NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 8781          NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 8782          NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
# 8783          NaN  SAO PAULO - INTERLAGOS  -23,724501  -46,677501       771
#
# [8784 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
#        'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#        'RADIACAO GLOBAL (Kj/m²)',
#        'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
#        'TEMPERATURA DO PONTO DE ORVALHO (°C)',
#        'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'UMIDADE RELATIVA DO AR, HORARIA (%)',
#        'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
#        'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19'],
#       dtype='object')

# %%
df_test_mudar_nome_col = df.rename(columns={'Data': 'Data', 
                                            'Hora UTC': 'Hora(UTC)', 
                                            'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)': 'Chuva',
                                            'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)': 'Pres',
                                            'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)': 'Pres.max',
                                            'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)': 'Pres.min',
                                            'RADIACAO GLOBAL (Kj/m²)': 'Radiacao',
                                            'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'Temp',
                                            'TEMPERATURA DO PONTO DE ORVALHO (°C)': 'Temp.orvalho',
                                            'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)': 'Temp.max',
                                            'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)': 'Temp.min',
                                            'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)': 'Temp.orvalho.max',
                                            'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)': 'Temp.orvalho.min',
                                            'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)': 'Umid.max',
                                            'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)': 'Umid.min',
                                            'UMIDADE RELATIVA DO AR, HORARIA (%)': 'Umid',
                                            'VENTO, DIREÇÃO HORARIA (gr) (° (gr))': 'Dir.vento', 
                                            'VENTO, RAJADA MAXIMA (m/s)': 'Rajada.vento',
                                            'VENTO, VELOCIDADE HORARIA (m/s)': 'Vel.vento'})
df_test_mudar_nome_col
# Out:
#             Data Hora(UTC) Chuva   Pres Pres.max Pres.min Radiacao  Temp  \
# 0     2020/01/01  0000 UTC     0    938    938,1    937,5      NaN  24,1
# 1     2020/01/01  0100 UTC     0  938,7    938,7    937,9      NaN  24,6
# 2     2020/01/01  0200 UTC     0  938,4    938,7    938,4      NaN  23,3
# 3     2020/01/01  0300 UTC     0    938    938,4      938      NaN  22,4
# 4     2020/01/01  0400 UTC     0  937,9      938    937,9      NaN  23,1
# ...          ...       ...   ...    ...      ...      ...      ...   ...
# 8779  2020/12/31  1900 UTC   2,8  941,1    942,1    941,1       76  20,9
# 8780  2020/12/31  2000 UTC    ,8  941,3    941,3    940,9    134,7  21,4
# 8781  2020/12/31  2100 UTC     0  941,7    941,7    941,1    198,8  21,8
# 8782  2020/12/31  2200 UTC    ,8  942,5    942,5    941,7     31,3  20,9
# 8783  2020/12/31  2300 UTC   1,8  942,4    942,6    942,2       ,6  20,4
#
#      Temp.orvalho Temp.max Temp.min Temp.orvalho.max Temp.orvalho.min  \
# 0            19,9       26     23,9             19,9             17,5
# 1            19,3     25,3     24,1             19,9               18
# 2              19     24,8     23,3             19,4             18,4
# 3            19,1     23,3     22,4             19,1             18,6
# 4              19     23,2     22,1             19,2             18,6
# ...           ...      ...      ...              ...              ...
# 8779         20,3     22,2     20,8             21,5             20,2
# 8780         20,8     21,4     20,9             20,8             20,3
# 8781         21,2       22     21,4             21,3             20,8
# 8782         20,2     21,9     20,9             21,3             20,2
# 8783         19,8     20,9     20,4             20,2             19,8
#
#       Umid.max  Umid.min  Umid  Dir.vento Rajada.vento Vel.vento  Unnamed: 19
# 0           78        60    77        169          7,1         1          NaN
# 1           77        64    73        126          5,3        ,4          NaN
# 2           77        68    77        107          2,7         0          NaN
# 3           81        77    81        330           ,9         0          NaN
# 4           82        75    77        308          1,4         0          NaN
# ...        ...       ...   ...        ...          ...       ...          ...
# 8779        96        95    96        135          4,6         0          NaN
# 8780        96        96    96         97            0         0          NaN
# 8781        96        96    96        155            0         0          NaN
# 8782        96        95    96        124          4,7         0          NaN
# 8783        97        96    97         88            0         0          NaN
#
# [8784 rows x 20 columns]

# %%
df_test_mudar_nome_col['Radicao']
# Out:
#             Data Hora(UTC) Chuva   Pres Pres.max Pres.min Radiacao  Temp  \
# 0     2020/01/01  0000 UTC     0    938    938,1    937,5      NaN  24,1
# 1     2020/01/01  0100 UTC     0  938,7    938,7    937,9      NaN  24,6
# 2     2020/01/01  0200 UTC     0  938,4    938,7    938,4      NaN  23,3
# 3     2020/01/01  0300 UTC     0    938    938,4      938      NaN  22,4
# 4     2020/01/01  0400 UTC     0  937,9      938    937,9      NaN  23,1
# ...          ...       ...   ...    ...      ...      ...      ...   ...
# 8779  2020/12/31  1900 UTC   2,8  941,1    942,1    941,1       76  20,9
# 8780  2020/12/31  2000 UTC    ,8  941,3    941,3    940,9    134,7  21,4
# 8781  2020/12/31  2100 UTC     0  941,7    941,7    941,1    198,8  21,8
# 8782  2020/12/31  2200 UTC    ,8  942,5    942,5    941,7     31,3  20,9
# 8783  2020/12/31  2300 UTC   1,8  942,4    942,6    942,2       ,6  20,4
#
#      Temp.orvalho Temp.max Temp.min Temp.orvalho.max Temp.orvalho.min  \
# 0            19,9       26     23,9             19,9             17,5
# 1            19,3     25,3     24,1             19,9               18
# 2              19     24,8     23,3             19,4             18,4
# 3            19,1     23,3     22,4             19,1             18,6
# 4              19     23,2     22,1             19,2             18,6
# ...           ...      ...      ...              ...              ...
# 8779         20,3     22,2     20,8             21,5             20,2
# 8780         20,8     21,4     20,9             20,8             20,3
# 8781         21,2       22     21,4             21,3             20,8
# 8782         20,2     21,9     20,9             21,3             20,2
# 8783         19,8     20,9     20,4             20,2             19,8
#
#       Umid.max  Umid.min  Umid  Dir.vento Rajada.vento Vel.vento  Unnamed: 19
# 0           78        60    77        169          7,1         1          NaN
# 1           77        64    73        126          5,3        ,4          NaN
# 2           77        68    77        107          2,7         0          NaN
# 3           81        77    81        330           ,9         0          NaN
# 4           82        75    77        308          1,4         0          NaN
# ...        ...       ...   ...        ...          ...       ...          ...
# 8779        96        95    96        135          4,6         0          NaN
# 8780        96        96    96         97            0         0          NaN
# 8781        96        96    96        155            0         0          NaN
# 8782        96        95    96        124          4,7         0          NaN
# 8783        97        96    97         88            0         0          NaN
#
# [8784 rows x 20 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].replace("UTC", " ")
df_test_mudar_nome_col
# Out:
#             Data Hora(UTC) Chuva   Pres Pres.max Pres.min Radiacao  Temp  \
# 0     2020/01/01  0000 UTC     0    938    938,1    937,5      NaN  24,1
# 1     2020/01/01  0100 UTC     0  938,7    938,7    937,9      NaN  24,6
# 2     2020/01/01  0200 UTC     0  938,4    938,7    938,4      NaN  23,3
# 3     2020/01/01  0300 UTC     0    938    938,4      938      NaN  22,4
# 4     2020/01/01  0400 UTC     0  937,9      938    937,9      NaN  23,1
# ...          ...       ...   ...    ...      ...      ...      ...   ...
# 8779  2020/12/31  1900 UTC   2,8  941,1    942,1    941,1       76  20,9
# 8780  2020/12/31  2000 UTC    ,8  941,3    941,3    940,9    134,7  21,4
# 8781  2020/12/31  2100 UTC     0  941,7    941,7    941,1    198,8  21,8
# 8782  2020/12/31  2200 UTC    ,8  942,5    942,5    941,7     31,3  20,9
# 8783  2020/12/31  2300 UTC   1,8  942,4    942,6    942,2       ,6  20,4
#
#      Temp.orvalho Temp.max Temp.min Temp.orvalho.max Temp.orvalho.min  \
# 0            19,9       26     23,9             19,9             17,5
# 1            19,3     25,3     24,1             19,9               18
# 2              19     24,8     23,3             19,4             18,4
# 3            19,1     23,3     22,4             19,1             18,6
# 4              19     23,2     22,1             19,2             18,6
# ...           ...      ...      ...              ...              ...
# 8779         20,3     22,2     20,8             21,5             20,2
# 8780         20,8     21,4     20,9             20,8             20,3
# 8781         21,2       22     21,4             21,3             20,8
# 8782         20,2     21,9     20,9             21,3             20,2
# 8783         19,8     20,9     20,4             20,2             19,8
#
#       Umid.max  Umid.min  Umid  Dir.vento Rajada.vento Vel.vento  Unnamed: 19
# 0           78        60    77        169          7,1         1          NaN
# 1           77        64    73        126          5,3        ,4          NaN
# 2           77        68    77        107          2,7         0          NaN
# 3           81        77    81        330           ,9         0          NaN
# 4           82        75    77        308          1,4         0          NaN
# ...        ...       ...   ...        ...          ...       ...          ...
# 8779        96        95    96        135          4,6         0          NaN
# 8780        96        96    96         97            0         0          NaN
# 8781        96        96    96        155            0         0          NaN
# 8782        96        95    96        124          4,7         0          NaN
# 8783        97        96    97         88            0         0          NaN
#
# [8784 rows x 20 columns]

# %%
from datetime import *

df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].replace("UTC","")

def tratar_hora(hora):
    return hora.replace("UTC","")

df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].apply(lambda x: tratar_hora(x))

#df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].apply(lambda x: datetime.datetime(x.strip()))

df_test_mudar_nome_col
# Out:
#             Data Hora(UTC) Chuva   Pres Pres.max Pres.min Radiacao  Temp  \
# 0     2020/01/01     0000      0    938    938,1    937,5      NaN  24,1
# 1     2020/01/01     0100      0  938,7    938,7    937,9      NaN  24,6
# 2     2020/01/01     0200      0  938,4    938,7    938,4      NaN  23,3
# 3     2020/01/01     0300      0    938    938,4      938      NaN  22,4
# 4     2020/01/01     0400      0  937,9      938    937,9      NaN  23,1
# ...          ...       ...   ...    ...      ...      ...      ...   ...
# 8779  2020/12/31     1900    2,8  941,1    942,1    941,1       76  20,9
# 8780  2020/12/31     2000     ,8  941,3    941,3    940,9    134,7  21,4
# 8781  2020/12/31     2100      0  941,7    941,7    941,1    198,8  21,8
# 8782  2020/12/31     2200     ,8  942,5    942,5    941,7     31,3  20,9
# 8783  2020/12/31     2300    1,8  942,4    942,6    942,2       ,6  20,4
#
#      Temp.orvalho Temp.max Temp.min Temp.orvalho.max Temp.orvalho.min  \
# 0            19,9       26     23,9             19,9             17,5
# 1            19,3     25,3     24,1             19,9               18
# 2              19     24,8     23,3             19,4             18,4
# 3            19,1     23,3     22,4             19,1             18,6
# 4              19     23,2     22,1             19,2             18,6
# ...           ...      ...      ...              ...              ...
# 8779         20,3     22,2     20,8             21,5             20,2
# 8780         20,8     21,4     20,9             20,8             20,3
# 8781         21,2       22     21,4             21,3             20,8
# 8782         20,2     21,9     20,9             21,3             20,2
# 8783         19,8     20,9     20,4             20,2             19,8
#
#       Umid.max  Umid.min  Umid  Dir.vento Rajada.vento Vel.vento  Unnamed: 19
# 0           78        60    77        169          7,1         1          NaN
# 1           77        64    73        126          5,3        ,4          NaN
# 2           77        68    77        107          2,7         0          NaN
# 3           81        77    81        330           ,9         0          NaN
# 4           82        75    77        308          1,4         0          NaN
# ...        ...       ...   ...        ...          ...       ...          ...
# 8779        96        95    96        135          4,6         0          NaN
# 8780        96        96    96         97            0         0          NaN
# 8781        96        96    96        155            0         0          NaN
# 8782        96        95    96        124          4,7         0          NaN
# 8783        97        96    97         88            0         0          NaN
#
# [8784 rows x 20 columns]

# %%
df_test_mudar_nome_col['datahora'] = df_test_mudar_nome_col.apply(lambda row: pd.to_datetime(f'{row["Data"]} {row["Hora(UTC)"]}'), axis=1)

# %%
(df_test_mudar_nome_col['datahora'].dt.hour > 22) or (df_test_mudar_nome_col['datahora'].dt.hour < 8)
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#         ..
# 8779    19
# 8780    20
# 8781    21
# 8782    22
# 8783    23
# Name: datahora, Length: 8784, dtype: int64

# %%
df_test_mudar_nome_col
# Out:
#             Data Hora(UTC) Chuva   Pres Pres.max Pres.min Radiacao  Temp  \
# 0     2020/01/01     0000      0    938    938,1    937,5      NaN  24,1
# 1     2020/01/01     0100      0  938,7    938,7    937,9      NaN  24,6
# 2     2020/01/01     0200      0  938,4    938,7    938,4      NaN  23,3
# 3     2020/01/01     0300      0    938    938,4      938      NaN  22,4
# 4     2020/01/01     0400      0  937,9      938    937,9      NaN  23,1
# ...          ...       ...   ...    ...      ...      ...      ...   ...
# 8779  2020/12/31     1900    2,8  941,1    942,1    941,1       76  20,9
# 8780  2020/12/31     2000     ,8  941,3    941,3    940,9    134,7  21,4
# 8781  2020/12/31     2100      0  941,7    941,7    941,1    198,8  21,8
# 8782  2020/12/31     2200     ,8  942,5    942,5    941,7     31,3  20,9
# 8783  2020/12/31     2300    1,8  942,4    942,6    942,2       ,6  20,4
#
#      Temp.orvalho Temp.max  ... Temp.orvalho.max Temp.orvalho.min Umid.max  \
# 0            19,9       26  ...             19,9             17,5       78
# 1            19,3     25,3  ...             19,9               18       77
# 2              19     24,8  ...             19,4             18,4       77
# 3            19,1     23,3  ...             19,1             18,6       81
# 4              19     23,2  ...             19,2             18,6       82
# ...           ...      ...  ...              ...              ...      ...
# 8779         20,3     22,2  ...             21,5             20,2       96
# 8780         20,8     21,4  ...             20,8             20,3       96
# 8781         21,2       22  ...             21,3             20,8       96
# 8782         20,2     21,9  ...             21,3             20,2       96
# 8783         19,8     20,9  ...             20,2             19,8       97
#
#       Umid.min  Umid  Dir.vento  Rajada.vento Vel.vento Unnamed: 19  \
# 0           60    77        169           7,1         1         NaN
# 1           64    73        126           5,3        ,4         NaN
# 2           68    77        107           2,7         0         NaN
# 3           77    81        330            ,9         0         NaN
# 4           75    77        308           1,4         0         NaN
# ...        ...   ...        ...           ...       ...         ...
# 8779        95    96        135           4,6         0         NaN
# 8780        96    96         97             0         0         NaN
# 8781        96    96        155             0         0         NaN
# 8782        95    96        124           4,7         0         NaN
# 8783        96    97         88             0         0         NaN
#
#                 datahora
# 0    2020-01-01 00:00:00
# 1    2020-01-01 01:00:00
# 2    2020-01-01 02:00:00
# 3    2020-01-01 03:00:00
# 4    2020-01-01 04:00:00
# ...                  ...
# 8779 2020-12-31 19:00:00
# 8780 2020-12-31 20:00:00
# 8781 2020-12-31 21:00:00
# 8782 2020-12-31 22:00:00
# 8783 2020-12-31 23:00:00
#
# [8784 rows x 21 columns]

# %%
def tratar_radiacao(hora, radiacao):
    if (df_test_mudar_nome_col['datahora'].dt.hour > 22) or (df_test_mudar_nome_col['datahora'].dt.hour < 8):
        if radiacao == 'NaN':
            radiacao = 0
    return radiacao
df_test_mudar_nome_col['Radiacao'] = df_test_mudar_nome_col.apply(lambda x: tratar_radiacao(x['datahora'],x['Radiacao']),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <cell line: 6>()
#       4             radiacao = 0
#       5     return radiacao
# ----> 6 df_test_mudar_nome_col['Radiacao'] = df_test_mudar_nome_col.apply(lambda x: tratar_radiacao(x['datahora'],x['Radiacao']),axis=1)
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/frame.py:8833, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8822 from pandas.core.apply import frame_apply
#    8824 op = frame_apply(
#    8825     self,
#    8826     func=func,
#    (...)
#    8831     kwargs=kwargs,
#    8832 )
# -> 8833 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [73], in <lambda>(x)
#       4             radiacao = 0
#       5     return radiacao
# ----> 6 df_test_mudar_nome_col['Radiacao'] = df_test_mudar_nome_col.apply(lambda x: tratar_radiacao(x['datahora'],x['Radiacao']),axis=1)
#
# Input In [73], in tratar_radiacao(hora, radiacao)
#       1 def tratar_radiacao(hora, radiacao):
# ----> 2     if (df_test_mudar_nome_col['datahora'].dt.hour > 22) or (df_test_mudar_nome_col['datahora'].dt.hour < 8):
#       3         if radiacao == 'NaN':
#       4             radiacao = 0
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/generic.py:1535, in NDFrame.__nonzero__(self)
#    1533 @final
#    1534 def __nonzero__(self):
# -> 1535     raise ValueError(
#    1536         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1537         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1538     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
from datetime import *

df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].replace("UTC","")

def tratar_hora(hora):
    return hora.replace("UTC","")

df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].apply(lambda x: tratar_hora(x))

#df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].apply(lambda x: datetime.datetime(x.strip()))

df_test_mudar_nome_col['Hora(UTC)'] = int(df_test_mudar_nome_col['Hora(UTC)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 12>()
#       8 df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].apply(lambda x: tratar_hora(x))
#      10 #df_test_mudar_nome_col['Hora(UTC)'] = df_test_mudar_nome_col['Hora(UTC)'].apply(lambda x: datetime.datetime(x.strip()))
# ---> 12 df_test_mudar_nome_col['Hora(UTC)'] = int(df_test_mudar_nome_col['Hora(UTC)'])
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/series.py:191, in _coerce_method.<locals>.wrapper(self)
#     189 if len(self) == 1:
#     190     return converter(self.iloc[0])
# --> 191 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df_test_mudar_nome_col.dtypes
# Out:
# Data                 object
# Hora(UTC)            object
# Chuva                object
# Pres                 object
# Pres.max             object
# Pres.min             object
# Radiacao             object
# Temp                 object
# Temp.orvalho         object
# Temp.max             object
# Temp.min             object
# Temp.orvalho.max     object
# Temp.orvalho.min     object
# Umid.max              int64
# Umid.min              int64
# Umid                  int64
# Dir.vento             int64
# Rajada.vento         object
# Vel.vento            object
# Unnamed: 19         float64
# dtype: object

# %%
df_test_mudar_nome_col['Hora(UTC)'] = pd.to_datetime(df_test_mudar_nome_col['Hora(UTC)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: day is out of range for month: 0000
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:547, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: day is out of range for month
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df_test_mudar_nome_col['Hora(UTC)'] = pd.to_datetime(df_test_mudar_nome_col['Hora(UTC)'], utc=True)
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045             result = arg.tz_localize(tz)
#    1046 elif isinstance(arg, ABCSeries):
# -> 1047     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048     if not cache_array.empty:
#    1049         result = arg.map(cache_array)
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: day is out of range for month: 0000

# %%
df2['Hora(UTC)'] = df2['Hora(UTC)'].replace("(UTC)","")

#def tratar_hora(hora):
#    return hora.replace("UTC","")
#df2['Hora(UCT)'] = df2['Hora(UCT)'].apply(lambda x: classe_chuva(x))

# %%
df_test_mudar_nome_col['Hora UTC']=df_test_mudar_nome_col['Hora UTC'].apply(lambda x: x.replace('UTC',''))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hora UTC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 df_test_mudar_nome_col['Hora UTC']=df_test_mudar_nome_col['Hora UTC'].apply(lambda x: x.replace('UTC',''))
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.pyenv/versions/3.8.12/envs/rain-prediction-machine/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Hora UTC'
