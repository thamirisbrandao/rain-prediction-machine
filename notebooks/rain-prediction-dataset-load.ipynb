# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
path = '../raw_data/SP'
files = [f for f in listdir(path) if isfile(join(path, f))]
print(files[0])
# Out:
# INMET_SE_SP_A735_JOSE BONIFACIO_01-01-2021_A_31-12-2021.CSV

# %%
df = pd.read_csv(f'../raw_data/SP/{files[0]}', sep=';', skiprows=8, encoding="ISO-8859-1")
df['Estaçao']=files[0].split('_')[4]

# %%
df.drop(columns=['Unnamed: 19'])
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                              NaN
# 1     2021/01/01  0100 UTC                              NaN
# 2     2021/01/01  0200 UTC                              NaN
# 3     2021/01/01  0300 UTC                              NaN
# 4     2021/01/01  0400 UTC                              NaN
# ...          ...       ...                              ...
# 8755  2021/12/31  1900 UTC                              NaN
# 8756  2021/12/31  2000 UTC                              NaN
# 8757  2021/12/31  2100 UTC                              NaN
# 8758  2021/12/31  2200 UTC                              NaN
# 8759  2021/12/31  2300 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# ...

# %%
files[2].split('_')
# Out:
# ['INMET',
#  'SE',
#  'SP',
#  'A746',
#  'BARRA DO TURVO',
#  '01-01-2021',
#  'A',
#  '31-12-2021.CSV']

# %%
teste=df
teste['Estaçao']=files[0].split('_')[4]
teste.drop(columns=['Unnamed: 19'])
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                              NaN
# 1     2021/01/01  0100 UTC                              NaN
# 2     2021/01/01  0200 UTC                              NaN
# 3     2021/01/01  0300 UTC                              NaN
# 4     2021/01/01  0400 UTC                              NaN
# ...          ...       ...                              ...
# 8755  2021/12/31  1900 UTC                              NaN
# 8756  2021/12/31  2000 UTC                              NaN
# 8757  2021/12/31  2100 UTC                              NaN
# 8758  2021/12/31  2200 UTC                              NaN
# 8759  2021/12/31  2300 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# ...

# %%
import seaborn as sns

sns.displot(df)
