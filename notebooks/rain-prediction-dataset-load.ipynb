# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
#cria variavel file com lista de arquivos
path = '../raw_data/SP'
files = [f for f in listdir(path) if isfile(join(path, f))]
print(files[0])
# Out:
# INMET_SE_SP_A735_JOSE BONIFACIO_01-01-2021_A_31-12-2021.CSV

# %%
#fazer list com os dataframes

df_list = []
for file in range(0,88):
    df = pd.read_csv(f'../raw_data/SP/{files[file]}', sep=';', skiprows=8, encoding="ISO-8859-1", decimal=',')
    lat_log_alt = pd.read_csv(f'../raw_data/SP/{files[file]}', sep=';', skiprows=4, 
                          nrows=3, encoding="ISO-8859-1", decimal=',', names=['lat_lon_alt','valor'])
    df['Estaçao']=files[file].split('_')[4]
    df['Latitude']=lat_log_alt['valor'][0] 
    df['Longitude']=lat_log_alt['valor'][1] 
    df['Altitude']=lat_log_alt['valor'][2]
    df_list.append(df)
df_list
    
#fundir os dataframes no dataframe vazio

full_df = pd.concat(df_list)
full_df
df2 = full_df.copy()

# %%
lat_log_alt
# Out:
#   lat_lon_alt       valor
# 0   LATITUDE:  -23.724501
# 1  LONGITUDE:  -46.677501
# 2   ALTITUDE:  771.000000

# %%
df2
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                               NaN
# 1     2021/01/01  0100 UTC                               NaN
# 2     2021/01/01  0200 UTC                               NaN
# 3     2021/01/01  0300 UTC                               NaN
# 4     2021/01/01  0400 UTC                               NaN
# ...          ...       ...                               ...
# 8755  2021/12/31  1900 UTC                              31.2
# 8756  2021/12/31  2000 UTC                               1.4
# 8757  2021/12/31  2100 UTC                               2.4
# 8758  2021/12/31  2200 UTC                               0.0
# 8759  2021/12/31  2300 UTC                               0.2
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8755                                              919.6
# 8756                                              920.0
# 8757                                              919.9
# 8758                                              920.9
# 8759                                              921.0
#
#       PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 8755                                            919.8
# 8756                                            920.0
# 8757                                            920.1
# 8758                                            920.9
# 8759                                            921.0
#
#       PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8755                                             919.5
# 8756                                             919.6
# 8757                                             919.9
# 8758                                             919.8
# 8759                                             920.7
#
#       RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                         NaN                                           NaN
# 1                         NaN                                           NaN
# 2                         NaN                                           NaN
# 3                         NaN                                           NaN
# 4                         NaN                                           NaN
# ...                       ...                                           ...
# 8755                     82.3                                          19.4
# 8756                    116.4                                          19.5
# 8757                    135.3                                          19.5
# 8758                     34.7                                          19.4
# 8759                      NaN                                          19.3
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8755                                  19.4
# 8756                                  19.5
# 8757                                  19.5
# 8758                                  19.4
# 8759                                  19.3
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                            NaN  ...
# 1                                            NaN  ...
# 2                                            NaN  ...
# 3                                            NaN  ...
# 4                                            NaN  ...
# ...                                          ...  ...
# 8755                                        20.2  ...
# 8756                                        19.7  ...
# 8757                                        19.7  ...
# 8758                                        19.7  ...
# 8759                                        19.5  ...
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 8755                                     100.0
# 8756                                     100.0
# 8757                                     100.0
# 8758                                     100.0
# 8759                                     100.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 8755                                100.0
# 8756                                100.0
# 8757                                100.0
# 8758                                100.0
# 8759                                100.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 8755                                 138.0                         4.1
# 8756                                 121.0                         4.6
# 8757                                 103.0                         2.6
# 8758                                 188.0                         2.6
# 8759                                 143.0                         2.6
#
#       VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19                 Estaçao  \
# 0                                 NaN          NaN          JOSE BONIFACIO
# 1                                 NaN          NaN          JOSE BONIFACIO
# 2                                 NaN          NaN          JOSE BONIFACIO
# 3                                 NaN          NaN          JOSE BONIFACIO
# 4                                 NaN          NaN          JOSE BONIFACIO
# ...                               ...          ...                     ...
# 8755                              1.9          NaN  SAO PAULO - INTERLAGOS
# 8756                              1.0          NaN  SAO PAULO - INTERLAGOS
# 8757                              0.8          NaN  SAO PAULO - INTERLAGOS
# 8758                              1.0          NaN  SAO PAULO - INTERLAGOS
# 8759                              0.5          NaN  SAO PAULO - INTERLAGOS
#
#        Latitude  Longitude  Altitude
# 0    -21.085556 -49.920278    408.35
# 1    -21.085556 -49.920278    408.35
# 2    -21.085556 -49.920278    408.35
# 3    -21.085556 -49.920278    408.35
# 4    -21.085556 -49.920278    408.35
# ...         ...        ...       ...
# 8755 -23.724501 -46.677501    771.00
# 8756 -23.724501 -46.677501    771.00
# 8757 -23.724501 -46.677501    771.00
# 8758 -23.724501 -46.677501    771.00
# 8759 -23.724501 -46.677501    771.00
#
# [771936 rows x 24 columns]

# %% [markdown]
# ## Rain rate intensity classification
#
#  <font color=blue>__Light rain__</font> - less than 2.5 mm/h (<0.1”/hr) or <0.04 mm/min (<0.0007”/min) rain rate, which for a 0.1 mm (0.004”) resolution rain gauge is 25 full tipping buckets per hour (25 pulses/hr).
#
#  <font color=blue>__Moderate rain__</font> - rain rate of fall is 2.6 to 7.5 mm/h (0.1 to 0.3”/hr) or 0.04 to 0.125 mm/min (0.0017 to 0.005”/hr), which for a 0.1 mm resolution rain gauge equals 26 to 75 full tipping buckets per hour (26 to 75 pulses/hr).
#
#  <font color=blue>__Heavy rain__</font> - rain rate is greater than 7.6 to 50 mm/h (0.3 to 2”/hr) or 0.125 to 0.83 mm/min (0.005" to 0.033”/min) which for a 0.1 mm resolution rain gauge equals 76 or more full tipping buckets per hour (76+ pulses/hr).
#
#  <font color=blue>__Violent rain__</font>: Can sometimes be used to characterize precipitation rates grater than >50 mm/hr (>2 in/hr) or >0.83 mm/min (>0.033”/min) which for a 0.1 mm resolution rain gauge equals 500 or more full tipping buckets per hour (500+ pulses/hr, 8+ pulses/minute).

# %%
def classe_chuva(precipitacao):
        
        mm=precipitacao
        
        if mm == 0:
            chuva = 'nao chove'
        elif mm >0 and mm <=2.5:
            chuva = 'fraca'
        elif mm >2.5 and mm<=7.5:
            chuva = 'moderada'
        elif mm >7.5 and mm<=50:
            chuva = 'forte'
        else:
            chuva = 'muito forte'
        return chuva

# %%
df2['classe_chuva']=df['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].apply(lambda x: classe_chuva(x))

# %%
df2.drop(columns=['Unnamed: 19'],inplace=True)
df2
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                               NaN
# 1     2021/01/01  0100 UTC                               NaN
# 2     2021/01/01  0200 UTC                               NaN
# 3     2021/01/01  0300 UTC                               NaN
# 4     2021/01/01  0400 UTC                               NaN
# ...          ...       ...                               ...
# 8755  2021/12/31  1900 UTC                              31.2
# 8756  2021/12/31  2000 UTC                               1.4
# 8757  2021/12/31  2100 UTC                               2.4
# 8758  2021/12/31  2200 UTC                               0.0
# 8759  2021/12/31  2300 UTC                               0.2
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8755                                              919.6
# 8756                                              920.0
# 8757                                              919.9
# 8758                                              920.9
# 8759                                              921.0
#
#       PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 8755                                            919.8
# 8756                                            920.0
# 8757                                            920.1
# 8758                                            920.9
# 8759                                            921.0
#
#       PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8755                                             919.5
# 8756                                             919.6
# 8757                                             919.9
# 8758                                             919.8
# 8759                                             920.7
#
#       RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                         NaN                                           NaN
# 1                         NaN                                           NaN
# 2                         NaN                                           NaN
# 3                         NaN                                           NaN
# 4                         NaN                                           NaN
# ...                       ...                                           ...
# 8755                     82.3                                          19.4
# 8756                    116.4                                          19.5
# 8757                    135.3                                          19.5
# 8758                     34.7                                          19.4
# 8759                      NaN                                          19.3
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8755                                  19.4
# 8756                                  19.5
# 8757                                  19.5
# 8758                                  19.4
# 8759                                  19.3
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 0                                            NaN  ...
# 1                                            NaN  ...
# 2                                            NaN  ...
# 3                                            NaN  ...
# 4                                            NaN  ...
# ...                                          ...  ...
# 8755                                        20.2  ...
# 8756                                        19.7  ...
# 8757                                        19.7  ...
# 8758                                        19.7  ...
# 8759                                        19.5  ...
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 8755                                     100.0
# 8756                                     100.0
# 8757                                     100.0
# 8758                                     100.0
# 8759                                     100.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 8755                                100.0
# 8756                                100.0
# 8757                                100.0
# 8758                                100.0
# 8759                                100.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
# ...                                    ...                         ...
# 8755                                 138.0                         4.1
# 8756                                 121.0                         4.6
# 8757                                 103.0                         2.6
# 8758                                 188.0                         2.6
# 8759                                 143.0                         2.6
#
#       VENTO, VELOCIDADE HORARIA (m/s)                 Estaçao   Latitude  \
# 0                                 NaN          JOSE BONIFACIO -21.085556
# 1                                 NaN          JOSE BONIFACIO -21.085556
# 2                                 NaN          JOSE BONIFACIO -21.085556
# 3                                 NaN          JOSE BONIFACIO -21.085556
# 4                                 NaN          JOSE BONIFACIO -21.085556
# ...                               ...                     ...        ...
# 8755                              1.9  SAO PAULO - INTERLAGOS -23.724501
# 8756                              1.0  SAO PAULO - INTERLAGOS -23.724501
# 8757                              0.8  SAO PAULO - INTERLAGOS -23.724501
# 8758                              1.0  SAO PAULO - INTERLAGOS -23.724501
# 8759                              0.5  SAO PAULO - INTERLAGOS -23.724501
#
#       Longitude  Altitude classe_chuva
# 0    -49.920278    408.35    nao chove
# 1    -49.920278    408.35    nao chove
# 2    -49.920278    408.35    nao chove
# 3    -49.920278    408.35    nao chove
# 4    -49.920278    408.35    nao chove
# ...         ...       ...          ...
# 8755 -46.677501    771.00        forte
# 8756 -46.677501    771.00        fraca
# 8757 -46.677501    771.00        fraca
# 8758 -46.677501    771.00    nao chove
# 8759 -46.677501    771.00        fraca
#
# [771936 rows x 24 columns]

# %%
df2['DataHora']=df2.apply(lambda x: pd.to_datetime(f"{x['Data']} {x['Hora UTC']}"), axis=1)

# %%
def tratar_radiacao(hora,radiacao):
    hora=datetime.time.strftime()
    if (df2['hora'].dt.hour > 22) and (df2['hora'].dt.hour < 8):
        if radiacao == 'NaN':
            radiacao = 0
    return radiacao

# %%
df2['RADIACAO GLOBAL (Kj/m²)'] = df2.apply(lambda x: tratar_radiacao(x['DataHora'],x['RADIACAO GLOBAL (Kj/m²)']),axis=1)

# %%
import matplotlib.pyplot as plt

plt.plot
